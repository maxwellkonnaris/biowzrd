# %%
import csv
import time
from datetime import datetime
from Bio import Entrez

Entrez.email = "mak6930@psu.edu"  # Replace with your email
Entrez.api_key = "9c9e61f98934800c1aab47c4066f394cde08"  # Replace with your API key

pmid_study_pairs = [('29143816', 'Vandeputte2017'),
 ('34795283', 'Vandeputte2021'),
 ('31209308', 'Viera-Silva2019'),
 ('35130830', 'Dreier2022'),
 ('39572788', 'Pereira2023'),
 ('37938658', 'VandeVelde2022'),
 ('33654104', 'Liao2021'),
 ('33594005', 'Marotz2021'),
 ('27329048', 'Stammler2016'),
 ('35927748', 'Krawczyk2022'),
 ('39364592', 'Alessandri2024'),
 ('30666957', 'Contijoch2019 16S'),
 ('30666957', 'Contijoch2019'),
 ('37106038', 'Maghini2023'),
 ('32433607', 'MetaCardis2020'),
 ('34880489', 'MetaCardis2021'),
 ('35177860', 'MetaCardis2024'),
 ('34580445', 'Global2024 (Aggarwala 2020)'),
 ('32437658', 'Global2024 (Ang 2020)'),
 ('31611867', 'Global2024 (Araos 2019)'),
 ('34248876', 'Global2024 (Bai 2021)'),
 ('33303685', 'Global2024 (Baruch 2021)'),
 ('32511695', 'Global2024 (BarYoseph 2020)'),
 ('28449715', 'Global2024 (Bedarf 2017)'),
 ('29228901', 'Global2024 (Bengtsson-Palme 2015)'),
 ('36691982', 'Global2024 (Boktor 2022)'),
 ('27409808', 'Global2024 (Brito 2017)'),
 ('27723761', 'Global2024 (Buschart 2016)'),
 ('26288277', 'Global2024 (Damman 2015)'),
 ('33542131', 'Global2024 (Davar 2021)'),
 ('25991682', 'Global2024 (David 2015)'),
 ('30799264', 'Global2024 (DeFillipis 2019)'),
 ('35115705', 'Global2024 (Derosa 2022)'),
 ('30698687', 'Global2024 (Dhakan 2019)'),
 ('32477962', 'Global2024 (Duan 2020)'),
 ('25758642', 'Global2024 (Feng 2015)'),
 ('NA', 'Global2024 (Ferretti 2023)'),
 ('28923537', 'Global2024 (Frankel 2017)'),
 ('30531976', 'Global2024 (Franzosa 2018)'),
 ('28821012', 'Global2024 (Fukuyama 2017)'),
 ('32390870', 'Global2024 (Gao 2020)'),
 ('32991818', 'Global2024 (Goll 2020)'),
 ('31888470', 'Global2024 (Goloshchapov 2019)'),
 ('29097493', 'Global2024 (Gopalakrishnan 2018)'),
 ('29183332', 'Global2024 (Hall 2017)'),
 ('30425247', 'Global2024 (Hansen 2018)'),
 ('28655159', 'Global2024 (He 2017)'),
 ('29942096', 'Global2024 (Hoyles 2018)'),
 ('31001490', 'Global2024 (Hu 2019)'),
 ('31778109', 'Global2024 (Huang 2020)'),
 ('33462272', 'Global2024 (Jacobson 2021)'),
 ('29018189', 'Global2024 (Jie 2017)'),
 ('35798742', 'Global2024 (Jo 2022)'),
 ('36109637', 'Global2024 (Karcher 2022)'),
 ('23719380', 'Global2024 (Karlsson 2013)'),
 ('35260444', 'Global2024 (Kartal 2022)'),
 ('32544460', 'Global2024 (Kenny 2020)'),
 ('29786169', 'Global2024 (Kieser 2018)'),
 ('31435014', 'Global2024 (Kim 2019)'),
 ('33077744', 'Global2024 (Kim 2020)'),
 ('34446072', 'Global2024 (Kim 2021)'),
 ('26322033', 'Global2024 (Kinumaki 2015)'),
 ('33517786', 'Global2024 (Koopen 2021)'),
 ('28591632', 'Global2024 (Korem 2017)'),
 ('31916894', 'Global2024 (Kovtun 2020)'),
 ('28873967', 'Global2024 (Kuang 2019)'),
 ('28649413', 'Global2024 (Kumar 2017)'),
 ('30056386', 'Global2024 (Kushugulova 2018)'),
 ('33593430', 'Global2024 (Langdon 2021)'),
 ('35516807', 'Global2024 (Laske 2022)'),
 ('32665016', 'Global2024 (LeBastard 2019)'),
 ('28473000', 'Global2024 (Lee 2017)'),
 ('33020474', 'Global2024 (Lee 2020)'),
 ('35228751', 'Global2024 (Lee 2022)'),
 ('32585945', 'Global2024 (Leo 2020)'),
 ('35675435', 'Global2024 (Leung 2022)'),
 ('28143587', 'Global2024 (Li 2017)'),
 ('25482875', 'Global2024 (Lim 2014)'),
 ('27708392', 'Global2024 (Liu 2016)'),
 ('28628112', 'Global2024 (Liu 2017)'),
 ('31786155', 'Global2024 (Liu 2019)'),
 ('35087227', 'Global2024 (Liu 2022)'),
 ('31142855', 'Global2024 (Lloyd-Price 2019)'),
 ('30726303', 'Global2024 (Lokmer 2019)'),
 ('28467925', 'Global2024 (Loomba 2017)'),
 ('26919743', 'Global2024 (Louis 2016)'),
 ('30034377', 'Global2024 (Lu 2018)'),
 ('34650532', 'Global2024 (Mao 2022)'),
 ('29456073', 'Global2024 (Mardinoglu 2018)'),
 ('32916129', 'Global2024 (Mars 2020)'),
 ('29302014', 'Global2024 (Matson 2018)'),
 ('35228752', 'Global2024 (McCulloch 2022)'),
 ('29335554', 'Global2024 (Mehta 2018)'),
 ('NA', 'Global2024 (MetaHIT)'),
 ('32459982', 'Global2024 (Monaghan 2019)'),
 ('28827811', 'Global2024 (Moss 2017)'),
 ('36155191', 'Global2024 (Nagata 2022_1)'),
 ('35398347', 'Global2024 (Nagata 2022_2)'),
 ('28441964', 'Global2024 (Nagy-Szakal 2017)'),
 ('30838178', 'Global2024 (Nearing 2019)'),
 ('27077120', 'Global2024 (Noguera-Julian 2016)'),
 ('30010747', 'Global2024 (Nusbaum 2018)'),
 ('25807110', 'Global2024 (Obregon-Tito 2015)'),
 ('37845315', 'Global2024 (Odenwald 2023)'),
 ('31558359', 'Global2024 (ODonovan 2020_1)'),
 ('31935465', 'Global2024 (ODonovan 2020_2)'),
 ('31138673', 'Global2024 (Paez 2019)'),
 ('27306058', 'Global2024 (Palleja 2016)'),
 ('30349083', 'Global2024 (Palleja 2018)'),
 ('30661755', 'Global2024 (Pasolli 2019)'),
 ('27172044', 'Global2024 (Pehrsson 2016)'),
 ('31597568', 'Global2024 (Peters 2019)'),
 ('28797298', 'Global2024 (Petersen 2017)'),
 ('35337386', 'Global2024 (Podlesny 2020)'),
 ('37452065', 'Global2024 (Pomyen 2023)'),
 ('30974084', 'Global2024 (Poole 2019)'),
 ('31477907', 'Global2024 (Poyet 2019)'),
 ('NA', 'Global2024 (PRJEB29373 ankylosing)'),
 ('32844199', 'Global2024 (Qian 2020)'),
 ('23023125', 'Global2024 (Qin 2012)'),
 ('25079328', 'Global2024 (Qin 2014)'),
 ('25981789', 'Global2024 (Rampelli 2015)'),
 ('31526447', 'Global2024 (Ravi 2019)'),
 ('26359913', 'Global2024 (Raymond 2016)'),
 ('30057943', 'Global2024 (Richter 2018)'),
 ('31078141', 'Global2024 (Rocafort 2019)'),
 ('29486796', 'Global2024 (Rosa 2018)'),
 ('29097494', 'Global2024 (Routy 2018)'),
 ('26671671', 'Global2024 (Sankaranarayanan 2015)'),
 ('34325466', 'Global2024 (Sato 2021)'),
 ('27814509', 'Global2024 (Schirmer 2016)'),
 ('36109636', 'Global2024 (Schmidt 2022)'),
 ('33361321', 'Global2024 (Sharma 2020)'),
 ('29447696', 'Global2024 (Smillie 2018)'),
 ('35115599', 'Global2024 (Stege 2022)'),
 ('31462412', 'Global2024 (Stewart 2019)'),
 ('34381036', 'Global2024 (Strazar 2021)'),
 ('35194028', 'Global2024 (Tamburini 2022)'),
 ('36476263', 'Global2024 (Tee 2022)'),
 ('31607556', 'Global2024 (Tett 2019)'),
 ('36604748', 'Global2024 (Thirion 2023_1)'),
 ('37124355', 'Global2024 (Thirion 2023_2)'),
 ('31664237', 'Global2024 (Thomas 2019)'),
 ('35211481', 'Global2024 (Tian 2022)'),
 ('30388453', 'Global2024 (Vangay 2018)'),
 ('27542133', 'Global2024 (Vaughn 2016)'),
 ('34252073', 'Global2024 (Verma 2021)'),
 ('27171425', 'Global2024 (Vogtmann 2016)'),
 ('36376318', 'Global2024 (Wallen 2022)'),
 ('32241904', 'Global2024 (Wang 2020)'),
 ('37069665', 'Global2024 (Watson 2021)'),
 ('28750650', 'Global2024 (Wen 2017)'),
 ('29688220', 'Global2024 (Whon 2018)'),
 ('30936547', 'Global2024 (Wirbel 2019)'),
 ('35505248', 'Global2024 (Worby 2022)'),
 ('31289141', 'Global2024 (Wu 2019)'),
 ('27818083', 'Global2024 (Xie 2016)'),
 ('31171880', 'Global2024 (Yachida 2019)'),
 ('30077182', 'Global2024 (Ye 2018)'),
 ('31928124', 'Global2024 (Ye 2020)'),
 ('33431578', 'Global2024 (Yeoh 2020)'),
 ('34805797', 'Global2024 (Yoshida 2021)'),
 ('26408641', 'Global2024 (Yu 2017)'),
 ('36289225', 'Global2024 (Yuan 2022)'),
 ('26590418', 'Global2024 (Zeevi 2015)'),
 ('25432777', 'Global2024 (Zeller 2014)'),
 ('26214836', 'Global2024 (Zhang 2015)'),
 ('37828586', 'Global2024 (Zhang 2023)'),
 ('29123168', 'Global2024 (Zheng 2017)'),
 ('36113426', 'Global2024 (Zhou 2022)'),
 ('30081953', 'Global2024 (Zhu 2018)'),
 ('32235826', 'Global2024 (Zhu 2020)'),
 ('28094305', 'Global2024 (Zinkernagel 2017)'),
 ('30193112', 'Global2024 (Zmora 2018)'),
 ('31149718', 'Global2024 (Zuo 2019)'),
 ('31653902', 'Global2024 (Zysset-Burri 2019)'),
 ('38868437', 'NA'),
 ('39462312', 'NA'),
 ('35365767', 'NA'),
 ('39469457', 'NA'),
 ('38650647', 'NA'),
 ('33627867', 'NA'),
 ('32265316', 'NA'),
 ('39427011', 'NA'),
 ('34292157', 'NA'),
 ('36906688', 'NA'),
 ('29904073', 'NA'),
 ('28743816', 'NA'),
 ('38868349', 'NA'),
 ('39539550', 'NA'),
 ('37509067', 'NA'),
 ('39359400', 'NA'),
 ('37957272', 'NA'),
 ('35140695', 'NA'),
 ('27980100', 'NA'),
 ('36317886', 'NA'),
 ('39386005', 'NA'),
 ('38395981', 'NA'),
 ('31308552', 'NA'),
 ('39458307', 'NA'),
 ('37657523', 'NA'),
 ('38816402', 'NA'),
 ('26811868', 'NA'),
 ('31940382', 'NA'),
 ('38868437', 'NA'),
 ('33232664', 'NA'),
 ('34794510', 'NA'),
 ('20844569', 'NA'),
 ('29921326', 'NA'),
 ('32444602', 'NA'),
 ('36691592', 'NA'),
 ('29576979', 'NA'),
 ('27612291', 'NA'),
 ('30518681', 'NA'),
 ('31927795', 'NA'),
 ('39487198', 'NA'),
 ('38744972', 'NA'),
 ('37627387', 'NA'),
 ('36174236', 'NA'),
 ('22931831', 'NA'),
 ('28967885', 'NA'),
 ('35194029', 'NA'),
 ('23101633', 'NA'),
 ('26512100', 'NA'),
 ('24060124', 'NA'),
 ('19321416', 'NA'),
 ('24259713', 'NA'),
 ('23898195', 'NA'),
 ('29174952', 'NA'),
 ('21596954', 'NA'),
 ('32850498', 'NA'),
 ('28275097', 'NA'),
 ('33404537', 'NA'),
 ('30552195', 'NA'),
 ('32531278', 'NA'),
 ('32405027', 'NA'),
 ('34480872', 'NA'),
 ('34183063', 'NA'),
 ('31836840', 'NA'),
 ('36516223', 'NA'),
 ('38925544', 'NA'),
 ('33996619', 'NA'),
 ('33594005', 'NA'),
 ('40038838', 'NA')]


def fetch_pubmed_data(pmid):
    """Fetches data from PubMed with retry logic on error."""
    while True:
        try:
            handle = Entrez.efetch(db="pubmed", id=pmid, retmode="xml")
            records = Entrez.read(handle)
            handle.close()
            return records
        except Exception as e:
            print(f"Error fetching PMID {pmid}: {e}. Retrying in 30 seconds...")
            time.sleep(30)

# Output file
with open("study_data.csv", mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow([
        "PMID", "Study Identifier", "Title", "Authors", "Consortium", "Publication Year", "Link",
        "Measurement Type", "Abstract", "Journal", "Volume", "Issue", "Pages", "DOI", "PMCID",
        "Publication Types", "MeSH Terms", "Keywords", "Affiliations", "Grants", "Retrieved Date"
    ])

    for pmid, study_identifier in pmid_study_pairs:
        today = datetime.today().strftime("%Y-%m-%d")

        if pmid.lower() == "na":
            # If the PMID is NA, just output the study label with empty metadata
            writer.writerow([pmid, study_identifier] + [""] * 18 + [today])
            continue

        try:
            records = fetch_pubmed_data(pmid)
            article = records["PubmedArticle"][0]["MedlineCitation"]["Article"]
            citation = records["PubmedArticle"][0]["MedlineCitation"]
            pubmed_data = records["PubmedArticle"][0].get("PubmedData", {})

            pub_date = article["Journal"]["JournalIssue"]["PubDate"]
            pub_year = pub_date.get("Year", "Unknown")
            title = article.get("ArticleTitle", "")
            link = f"https://pubmed.ncbi.nlm.nih.gov/{pmid}/"

            abstract_text = article.get("Abstract", {}).get("AbstractText", "")
            if isinstance(abstract_text, list):
                abstract_text = " ".join(str(a) for a in abstract_text)

            authors = article.get("AuthorList", [])
            author_names = [f"{a['ForeName']} {a['LastName']}" for a in authors if "ForeName" in a and "LastName" in a]

            if study_identifier == "NA" and authors:
                first_author_lastname = authors[0].get("LastName", "Unknown")
                study_identifier = f"{first_author_lastname}{pub_year}"
            
            journal = article["Journal"].get("Title", "")
            volume = article["Journal"]["JournalIssue"].get("Volume", "")
            issue = article["Journal"]["JournalIssue"].get("Issue", "")
            pages = article.get("Pagination", {}).get("MedlinePgn", "")

            doi = pmcid = ""
            for id_elem in pubmed_data.get("ArticleIdList", []):
                id_type = id_elem.attributes.get("IdType", "")
                if id_type == "doi":
                    doi = str(id_elem)
                elif id_type == "pmc":
                    pmcid = str(id_elem)

            pub_types = [pt for pt in article.get("PublicationTypeList", [])]
            mesh_terms = [m["DescriptorName"] for m in citation.get("MeshHeadingList", [])]
            keyword_list = citation.get("KeywordList", [])
            keywords = [kw for group in keyword_list for kw in group]

            affiliations = []
            for author in authors:
                for aff in author.get("AffiliationInfo", []):
                    affiliations.append(aff.get("Affiliation", ""))

            grants = []
            for grant in citation.get("GrantList", []):
                agency = grant.get("Agency", "")
                grant_id = grant.get("GrantID", "")
                grants.append(f"{agency} ({grant_id})" if grant_id else agency)

            consortium = ""
            measurement_type = ""

            writer.writerow([
                pmid,
                study_identifier,
                title,
                ", ".join(author_names),
                consortium,
                pub_year,
                link,
                measurement_type,
                abstract_text,
                journal,
                volume,
                issue,
                pages,
                doi,
                pmcid,
                "; ".join(pub_types),
                "; ".join(mesh_terms),
                "; ".join(keywords),
                "; ".join(affiliations),
                "; ".join(grants),
                today
            ])

        except Exception as e:
            print(f"Final error for PMID {pmid}: {e}")
            writer.writerow([pmid, study_identifier, "Error retrieving data"] + ["Error"] * 18 + [today])

print("✅ CSV file 'study_data.csv' has been created.")

# %%
# # List of PubMed IDs 
# pmids = [
#     "29143816", "34795283", "31209308", "35130830", "39572788", "37938658", "33654104", "33594005",
#     "27329048", "35927748", "39364592", "30666957", "30666957", "37106038", "32433607", "34880489",
#     "35177860",
#     "34580445", "32437658", "31611867", "34248876", "33303685", "32511695", "28449715", "29228901", 
#     "36691982", "27409808", "27723761", "26288277", "33542131", "25991682", "30799264", "35115705", 
#     "30698687", "32477962", "25758642", "NA",       "28923537", "30531976", "28821012", "32390870", 
#     "32991818", "31888470", "29097493", "29183332", "30425247", "28655159", "29942096", "31001490", 
#     "31778109", "33462272", "29018189", "35798742", "36109637", "23719380", "35260444", "32544460", 
#     "29786169", "31435014", "33077744", "34446072", "26322033", "33517786", "28591632", "31916894", 
#     "28873967", "28649413", "30056386", "33593430", "35516807", "32665016", "28473000", "33020474", 
#     "35228751", "32585945", "35675435", "28143587", "25482875", "27708392", "28628112", "31786155", 
#     "35087227", "31142855", "30726303", "28467925", "26919743", "30034377", "34650532", "29456073", 
#     "32916129", "29302014", "35228752", "29335554", "NA",       "32459982", "28827811", "36155191", 
#     "35398347", "28441964", "30838178", "27077120", "30010747", "25807110", "37845315", "31558359", 
#     "31935465", "31138673", "27306058", "30349083", "30661755", "27172044", "31597568", "28797298", 
#     "35337386", "37452065", "30974084", "31477907", "NA",       "32844199", "23023125", "25079328", 
#     "25981789", "31526447", "26359913", "30057943", "31078141", "29486796", "29097494", "26671671", 
#     "34325466", "27814509", "36109636", "33361321", "29447696", "35115599", "31462412", "34381036", 
#     "35194028", "36476263", "31607556", "36604748", "37124355", "31664237", "35211481", "30388453", 
#     "27542133", "34252073", "27171425", "36376318", "32241904", "37069665", "28750650", "29688220", 
#     "30936547", "35505248", "31289141", "27818083", "31171880", "30077182", "31928124", "33431578", 
#     "34805797", "26408641", "36289225", "26590418", "25432777", "26214836", "37828586", "29123168", 
#     "36113426", "30081953", "32235826", "28094305", "30193112", "31149718", "31653902", "38868437",
#     "39462312", "35365767", "39469457", "38650647", "33627867", "32265316", "39427011", "34292157",
#     "36906688", "29904073", "28743816", "38868349", "39539550", "37509067", "39359400", "37957272",
#     "35140695", "27980100", "36317886", "39386005", "38395981", "31308552", "39458307", "37657523",
#     "38816402", "26811868", "31940382", "38868437", "33232664", "34794510", "20844569", "29921326",
#     "32444602", "36691592", "29576979", "27612291", "30518681", "31927795", "39487198", "38744972",
#     "37627387", "36174236", "22931831", "28967885", "35194029", "23101633", "26512100", "24060124",
#     "19321416", "24259713", "23898195", "29174952", "21596954", "32850498", "28275097", "33404537",
#     "30552195", "32531278", "32405027", "34480872", "34183063", "31836840", "36516223", "38925544",
#     "33996619", "33594005", "40038838"
# ] 

# global_studies = [
#     "Vandeputte2017","Vandeputte2021", "Viera-Silva2019","Dreier2022","Pereira2023", "VandeVelde2022",
#     "Liao2021", "Marotz2021" , "Stammler2016", "Krawczyk2022", "Alessandri2024", "Contijoch2019 16S", "Contijoch2019", 
#     "Maghini2023", "MetaCardis2020", "MetaCardis2021", "MetaCardis2024", "Global2024 (Aggarwala 2020)", "Global2024 (Ang 2020)", 
#     "Global2024 (Araos 2019)", "Global2024 (Bai 2021)",
#     "Global2024 (Baruch 2021)", "Global2024 (BarYoseph 2020)", "Global2024 (Bedarf 2017)", "Global2024 (Bengtsson-Palme 2015)",
#     "Global2024 (Boktor 2022)", "Global2024 (Brito 2017)", "Global2024 (Buschart 2016)", "Global2024 (Damman 2015)",
#     "Global2024 (Davar 2021)", "Global2024 (David 2015)", "Global2024 (DeFillipis 2019)", "Global2024 (Derosa 2022)",
#     "Global2024 (Dhakan 2019)", "Global2024 (Duan 2020)", "Global2024 (Feng 2015)", "Global2024 (Ferretti 2023)",
#     "Global2024 (Frankel 2017)", "Global2024 (Franzosa 2018)", "Global2024 (Fukuyama 2017)", "Global2024 (Gao 2020)",
#     "Global2024 (Goll 2020)", "Global2024 (Goloshchapov 2019)", "Global2024 (Gopalakrishnan 2018)", "Global2024 (Hall 2017)",
#     "Global2024 (Hansen 2018)", "Global2024 (He 2017)", "Global2024 (Hoyles 2018)", "Global2024 (Hu 2019)",
#     "Global2024 (Huang 2020)", "Global2024 (Jacobson 2021)", "Global2024 (Jie 2017)", "Global2024 (Jo 2022)",
#     "Global2024 (Karcher 2022)", "Global2024 (Karlsson 2013)", "Global2024 (Kartal 2022)", "Global2024 (Kenny 2020)",
#     "Global2024 (Kieser 2018)", "Global2024 (Kim 2019)", "Global2024 (Kim 2020)", "Global2024 (Kim 2021)",
#     "Global2024 (Kinumaki 2015)", "Global2024 (Koopen 2021)", "Global2024 (Korem 2017)", "Global2024 (Kovtun 2020)",
#     "Global2024 (Kuang 2019)", "Global2024 (Kumar 2017)", "Global2024 (Kushugulova 2018)", "Global2024 (Langdon 2021)",
#     "Global2024 (Laske 2022)", "Global2024 (LeBastard 2019)", "Global2024 (Lee 2017)", "Global2024 (Lee 2020)",
#     "Global2024 (Lee 2022)", "Global2024 (Leo 2020)", "Global2024 (Leung 2022)", "Global2024 (Li 2017)",
#     "Global2024 (Lim 2014)", "Global2024 (Liu 2016)", "Global2024 (Liu 2017)", "Global2024 (Liu 2019)",
#     "Global2024 (Liu 2022)", "Global2024 (Lloyd-Price 2019)", "Global2024 (Lokmer 2019)", "Global2024 (Loomba 2017)",
#     "Global2024 (Louis 2016)", "Global2024 (Lu 2018)", "Global2024 (Mao 2022)", "Global2024 (Mardinoglu 2018)",
#     "Global2024 (Mars 2020)", "Global2024 (Matson 2018)", "Global2024 (McCulloch 2022)", "Global2024 (Mehta 2018)",
#     "Global2024 (MetaHIT)", "Global2024 (Monaghan 2019)", "Global2024 (Moss 2017)", "Global2024 (Nagata 2022_1)",
#     "Global2024 (Nagata 2022_2)", "Global2024 (Nagy-Szakal 2017)", "Global2024 (Nearing 2019)", "Global2024 (Noguera-Julian 2016)",
#     "Global2024 (Nusbaum 2018)", "Global2024 (Obregon-Tito 2015)", "Global2024 (Odenwald 2023)", "Global2024 (ODonovan 2020_1)",
#     "Global2024 (ODonovan 2020_2)", "Global2024 (Paez 2019)", "Global2024 (Palleja 2016)", "Global2024 (Palleja 2018)",
#     "Global2024 (Pasolli 2019)", "Global2024 (Pehrsson 2016)", "Global2024 (Peters 2019)", "Global2024 (Petersen 2017)",
#     "Global2024 (Podlesny 2020)", "Global2024 (Pomyen 2023)", "Global2024 (Poole 2019)", "Global2024 (Poyet 2019)",
#     "Global2024 (PRJEB29373 ankylosing)", "Global2024 (Qian 2020)", "Global2024 (Qin 2012)", "Global2024 (Qin 2014)",
#     "Global2024 (Rampelli 2015)", "Global2024 (Ravi 2019)", "Global2024 (Raymond 2016)", "Global2024 (Richter 2018)",
#     "Global2024 (Rocafort 2019)", "Global2024 (Rosa 2018)", "Global2024 (Routy 2018)", "Global2024 (Sankaranarayanan 2015)",
#     "Global2024 (Sato 2021)", "Global2024 (Schirmer 2016)", "Global2024 (Schmidt 2022)", "Global2024 (Sharma 2020)",
#     "Global2024 (Smillie 2018)", "Global2024 (Stege 2022)", "Global2024 (Stewart 2019)", "Global2024 (Strazar 2021)",
#     "Global2024 (Tamburini 2022)", "Global2024 (Tee 2022)", "Global2024 (Tett 2019)", "Global2024 (Thirion 2023_1)",
#     "Global2024 (Thirion 2023_2)", "Global2024 (Thomas 2019)", "Global2024 (Tian 2022)", "Global2024 (Vangay 2018)",
#     "Global2024 (Vaughn 2016)", "Global2024 (Verma 2021)", "Global2024 (Vogtmann 2016)", "Global2024 (Wallen 2022)",
#     "Global2024 (Wang 2020)", "Global2024 (Watson 2021)", "Global2024 (Wen 2017)", "Global2024 (Whon 2018)",
#     "Global2024 (Wirbel 2019)", "Global2024 (Worby 2022)", "Global2024 (Wu 2019)", "Global2024 (Xie 2016)",
#     "Global2024 (Yachida 2019)", "Global2024 (Ye 2018)", "Global2024 (Ye 2020)", "Global2024 (Yeoh 2020)",
#     "Global2024 (Yoshida 2021)", "Global2024 (Yu 2017)", "Global2024 (Yuan 2022)", "Global2024 (Zeevi 2015)",
#     "Global2024 (Zeller 2014)", "Global2024 (Zhang 2015)", "Global2024 (Zhang 2023)", "Global2024 (Zheng 2017)",
#     "Global2024 (Zhou 2022)", "Global2024 (Zhu 2018)", "Global2024 (Zhu 2020)", "Global2024 (Zinkernagel 2017)",
#     "Global2024 (Zmora 2018)", "Global2024 (Zuo 2019)", "Global2024 (Zysset-Burri 2019)"
# ]

# pmid_study_pairs = []

# for i, pmid in enumerate(pmids):
#     if i < len(global_studies):
#         study = global_studies[i]
#     else:
#         study = "NA"
#     pmid_study_pairs.append((pmid, study))
